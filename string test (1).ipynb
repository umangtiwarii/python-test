# %%
#ques1
string1 = "hii i'm "
string2 = "umang tiwari"
concatenate = string1 + string2
print(concatenate)
# Out:
# hii i'm umang tiwari

# %%
 #ques2
# the difference between the + operator and joinmethod f() or concatenating string is the + is an arithematic operator
 # and join is an build in  method in python

# %%
#ques3

# %%
#ques4
string = "umang"
length = len(string)
print(length)
# Out:
# 5

# %%
#ques5
string = "umang"
print(string.capitalize())
# Out:
# Umang

# %%
#ques6
string = "UMANG"
print(string.lower())
# Out:
# umang

# %%
#ques7
string "hello world"
print(string.replace("world" , "WORLD",1))
# Out:
#   Cell In[25], line 1
#     string "hello world"
#            ^
# SyntaxError: invalid syntax

# %%
#ques8
string = "this is python class"
print("-".join(string.split()))
# Out:
# this-is-python-class

# %%
#ques9
string = "this is python class"
print(string.startswith("this"))
# Out:
# True

# %%
#ques10
string = "this is python class"
print(string.endswith("class"))
# Out:
# True

# %%
#ques11
string = "    this is python class"
print(string.lstrip())
# Out:
# this is python class

# %%
#ques 12
string = "this is python class"
print(string.index(" is"))
# Out:
# 4

# %%
#ques 13
string = "this is python class"
print(string.count(" is"))
# Out:
# 1

# %%
#ques14
string = "thisispythonclass"
print(string.isalpha())
# Out:
# True

# %%
#ques15
string = "5"
print(string.isdigit())
# Out:
# True

# %%
#ques17
str = "hello"
string =str[::-1]
print(string)
# Out:
# olleh
